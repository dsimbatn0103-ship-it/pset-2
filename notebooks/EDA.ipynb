# %%
import pandas as pd
import sqlalchemy
import math
from tqdm.auto import tqdm
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 7.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 9.2 MB/s  0:00:00
# ...

# %% [markdown]
# ## Se verifica que error OOM

# %%
# Iterar por cada mes en el rango
for year in range(start_year, end_year + 1):
    for month in range(1, 13):
        # Romper el ciclo si llegamos a un mes que está después del mes final
        if year == end_year and month > end_month:
            break

        # Construir la URL directamente con f-string
        URL = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month:02d}.parquet"
        print(f'Iniciando la descarga de los datos para el mes {year}-{month:02d}')

        try:
            # Descargar y cargar los datos
            datos_crudos = pd.read_parquet(URL)
            df_total = pd.concat([df_total, datos_crudos], ignore_index=True)
            print(f'Datos descargados del internet (NY TAXI GOV) para el mes {year}-{month:02d}')

            # Verificar cantidad de datos descargados
            print(f'Cantidad de datos: {datos_crudos.shape[0]}')
            print(datos_crudos.info())
            print(f'Columnas: {datos_crudos.columns}')  
            print(datos_crudos.head())
            print()

        except Exception as e:
            print(f"Mes faltante: {year}-{month:02d}")

# Guardar el DataFrame completo en un archivo local
df_total.to_parquet("yellow_tripdata_2023_2024.parquet")

# Verificar los primeros registros
print(f'Datos combinados de los dos años:')
print(df_total.head())

# URL = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet"

# print('Iniciando la descarga de los datos')

# datos_crudos = pd.read_parquet(URL)

# print('Datos descargados del internet (NY TAXI GOV)')

# print(f'Cantidad de datos: {datos_crudos.shape[0]}')
# print(datos_crudos.info())
# print(f'Columnas: {datos_crudos.columns}')  
# print(datos_crudos.head())
# print()
# Out:
# Descargando datos: 2023-01
# Filas descargadas: 3066766
# Creando tabla en PostgreSQL...
# Mes faltante o error en 2023-01: (psycopg2.OperationalError) could not translate host name "data-warehouse" to address: Name or service not known
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Descargando datos: 2023-02
# Filas descargadas: 2913955
# Creando tabla en PostgreSQL...
# Mes faltante o error en 2023-02: (psycopg2.OperationalError) could not translate host name "data-warehouse" to address: Name or service not known
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Descargando datos: 2023-03
# Filas descargadas: 3403766
# Creando tabla en PostgreSQL...
# Mes faltante o error en 2023-03: (psycopg2.OperationalError) could not translate host name "data-warehouse" to address: Name or service not known
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# Descargando datos: 2023-04
# Filas descargadas: 3288250
# ...

# %%
 URL = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet"

 print('Iniciando la descarga de los datos')

 datos_crudos = pd.read_parquet(URL)

 print('Datos descargados del internet (NY TAXI GOV)')

 print(f'Cantidad de datos: {datos_crudos.shape[0]}')
# Out:
# Iniciando la descarga de los datos
# Datos descargados del internet (NY TAXI GOV)
# Cantidad de datos: 3066766

# %%
# Snake case: hola_mundo
# Caml case: holaMundo - HolaMundo

# %%
# Valores ausentes afectan la calidad de datos -> Completitud

datos_crudos.isna().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          140225
# trip_distance                 0
# RatecodeID               140225
# store_and_fwd_flag       140225
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     140225
# Airport_fee              140225
# dtype: int64

# %%
datos_crudos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2846722 entries, 0 to 2846721
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
datos_crudos.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-09-01 00:15:37   2023-09-01 00:20:21              1.0
# 1         2  2023-09-01 00:18:40   2023-09-01 00:30:28              2.0
# 2         2  2023-09-01 00:35:01   2023-09-01 00:39:04              1.0
# 3         2  2023-09-01 00:45:45   2023-09-01 00:47:37              1.0
# 4         2  2023-09-01 00:01:23   2023-09-01 00:38:05              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.80         1.0                  N           163           230
# 1           2.34         1.0                  N           236           233
# 2           1.62         1.0                  N           162           236
# 3           0.74         1.0                  N           141           229
# 4           9.85         1.0                  N           138           230
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...
